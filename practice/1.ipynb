# %%
from urllib import request as url
import re
from collections import Counter

def wordcount(url_input):
    with url.urlopen(url_input) as doc:
        html = doc.read().decode()
        words = re.findall(r"\w+", html)
    
        frequency = Counter(words).most_common()
    return frequency


if __name__ == '__main__':
    result = wordcount("https://www.daum.net/")
    print(result)
# Out:
# [('class', 1060), ('data', 835), ('span', 771), ('tiara', 681), ('0', 646), ('position', 544), ('height', 539), ('background', 524), ('a', 445), ('net', 437), ('width', 420), ('top', 366), ('li', 341), ('div', 293), ('left', 278), ('layer', 275), ('daumcdn', 274), ('action', 272), ('hidden', 240), ('href', 236), ('margin', 236), ('name', 232), ('https', 223), ('color', 218), ('padding', 216), ('overflow', 206), ('t1', 201), ('font', 197), ('right', 171), ('display', 169), ('id', 168), ('daum', 166), ('os_mac', 166), ('text', 157), ('line', 155), ('size', 154), ('block', 139), ('src', 134), ('png', 133), ('daumtop_deco', 128), ('strong', 127), ('images', 126), ('1px', 118), ('frame_g', 117), ('absolute', 116), ('float', 116), ('url', 110), ('img', 103), ('suggestBox', 100), ('v', 90), ('keyboard_layer', 89), ('link_tit', 82), ('bottom', 81), ('today_layer', 81), ('12px', 79), ('img_thumb', 78), ('dd', 77), ('none', 77), ('relative', 77), ('thumb', 75), ('border', 74), ('screen_out', 73), ('align', 72), ('ir_wa', 72), ('20px', 70), ('16px', 69), ('alt', 69), ('view_slide', 68), ('13px', 67), ('cont_item', 66), ('amp', 66), ('img2', 66), ('fname', 66), ('tit_item', 64), ('link_thumb', 63), ('true', 62), ('op', 61), ('100', 60), ('11px', 60), ('14px', 60), ('2017', 60), ('link_item', 60), ('30px', 58), ('suggest_exact', 58), ('aria', 57), ('transform', 56), ('search', 55), ('ico_pctop', 55), ('kind', 55), ('ClickContent', 55), ('ordnum', 55), ('39', 55), ('solid', 54), ('2px', 54), ('panel_bloc', 54), ('http', 52), ('hover', 52), ('h3', 51), ('10px', 51), ('1', 50), ('thumb_g', 50), ('news', 49), ('em', 49), ('repeat', 49), ('group_keyboard', 49), ('hamny', 48), ('button', 46), ('15px', 46), ('EC', 46), ('com', 46), ('fff', 45), ('decoration', 45), ('index', 45), ('info_today', 45), ('8px', 44), ('11', 44), ('vertical', 43), ('inline', 43), ('space', 43), ('white', 42), ('888', 42), ('title', 41), ('image', 41), ('default', 41), ('indent', 40), ('txt_pctop', 40), ('18px', 40), ('클릭', 40), ('kakao', 40), ('GNB_서비스_더보기', 40), ('jpg', 40), ('fst', 39), ('ul', 38), ('no', 38), ('nowrap', 38), ('target', 38), ('레이어_서비스', 38), ('weight', 37), ('4px', 37), ('7px', 37), ('link_svc', 37), ('relay_special', 37), ('type', 36), ('z', 36), ('9px', 36), ('auto', 35), ('94', 35), ('_blank', 35), ('family', 34), ('sans', 34), ('serif', 34), ('36px', 34), ('60px', 34), ('60', 34), ('202006', 34), ('소재', 34), ('p', 33), ('letter', 33), ('spacing', 33), ('9999px', 33), ('3px', 33), ('gallery', 33), ('ellipsis', 32), ('154', 32), ('img_weather', 31), ('origin_item', 31), ('EB', 31), ('5px', 30), ('translateY', 30), ('normal', 29), ('hide', 29), ('transition', 29), ('max', 29), ('view_photo', 29), ('foot_daum', 28), ('6px', 28), ('100px', 28), ('wrap_tabcont', 28), ('list_ranking', 28), ('c_id', 28), ('h2', 27), ('q', 27), ('box_channel', 27), ('날씨', 27), ('dt', 26), ('40px', 26), ('on', 26), ('tit_tabcont', 26), ('story', 26), ('viewer', 26), ('118eff', 25), ('28px', 25), ('btn_keyboard', 25), ('22px', 25), ('ico_degree', 25), ('list_relay', 25), ('rtn', 25), ('오늘의', 25), ('영상', 25), ('카카오', 25), ('dl', 24), ('120px', 24), ('17px', 24), ('night', 24), ('service_layer', 24), ('txt_temper', 24), ('word', 24), ('media', 24), ('S308x188', 24), ('page_pctop', 23), ('login_my', 23), ('tot', 23), ('w', 23), ('DA', 23), ('45px', 22), ('ico_ws', 22), ('ico_vert', 21), ('ececec', 21), ('80px', 21), ('txt_part', 21), ('imp_id', 21), ('custom', 21), ('포토_데이터', 21), ('center', 20), ('num_pctop', 20), ('sort_service', 20), ('break', 20), ('ad', 20), ('C', 20), ('head_daum', 19), ('200px', 19), ('btn_page', 19), ('154px', 19), ('list_story', 19), ('box_photo', 19), ('tabindex', 19), ('txt', 19), ('tv', 19), ('script', 18), ('style', 18), ('222', 18), ('shortcut_g', 18), ('300px', 18), ('19px', 18), ('555', 18), ('ico_video', 18), ('list_thumb', 18), ('cover_g', 18), ('relay_general', 18), ('box_chextra', 18), ('EA', 18), ('quot', 18), ('운영_하단', 18), ('26px', 17), ( ...
